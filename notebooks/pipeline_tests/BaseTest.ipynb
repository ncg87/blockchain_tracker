# %%
import sys
import os
from pathlib import Path

# Get absolute path to project root
project_root = Path(os.getcwd()).resolve()
if project_root.name != "ncg87-blockchain_tracker":
    project_root = project_root.parent.parent  # Adjust if running from a subdirectory

sys.path.append(str(project_root))

# Add to Python path if not already there
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from config import Settings
from chains import BaseChainQuerier, BaseChainProcessor
from database import SQLDatabase, MongoDatabase, MongoQueryOperations
import logging

#logging.basicConfig(level=logging.INFO,
#                   format='%(asctime)s - %(levelname)s - %(message)s')

# %%
querier = BaseChainQuerier()
sql_database = SQLDatabase()
mongodb_database = MongoDatabase()
mongo_query_ops = MongoQueryOperations(mongodb_database)
processor = BaseChainProcessor(sql_database, mongodb_database, querier)

# %%
query = mongo_query_ops.get_recent_blocks('Base', 50)

# %%
for block in query:
    for i in range(1):
        processor.process_logs(block['block_number'], block['timestamp'])
# Out:
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error compressing block data: Object of type bytes is not JSON serializable
# Error processing logs for block 25018485: Object of type bytes is not JSON serializable
# Traceback (most recent call last):
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\chains\evm_models\evm_processor.py", line 213, in process_logs
#     self.mongodb_insert_ops.insert_evm_transactions(
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 61, in insert_evm_transactions
#     compressed_data = self._compress_data(logs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 16, in _compress_data
#     json_str = json.dumps(block_data)
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\__init__.py", line 231, in dumps
#     return _default_encoder.encode(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 200, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 258, in iterencode
#     return _iterencode(o, 0)
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 180, in default
#     raise TypeError(f'Object of type {o.__class__.__name__} '
# TypeError: Object of type bytes is not JSON serializable
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error compressing block data: Object of type HexBytes is not JSON serializable
# Error processing logs for block 25018484: Object of type HexBytes is not JSON serializable
# Traceback (most recent call last):
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\chains\evm_models\evm_processor.py", line 213, in process_logs
#     self.mongodb_insert_ops.insert_evm_transactions(
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 61, in insert_evm_transactions
#     compressed_data = self._compress_data(logs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 16, in _compress_data
#     json_str = json.dumps(block_data)
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\__init__.py", line 231, in dumps
#     return _default_encoder.encode(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 200, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 258, in iterencode
#     return _iterencode(o, 0)
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 180, in default
#     raise TypeError(f'Object of type {o.__class__.__name__} '
# TypeError: Object of type HexBytes is not JSON serializable
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error compressing block data: Object of type HexBytes is not JSON serializable
# Error processing logs for block 25018483: Object of type HexBytes is not JSON serializable
# Traceback (most recent call last):
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\chains\evm_models\evm_processor.py", line 213, in process_logs
#     self.mongodb_insert_ops.insert_evm_transactions(
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 61, in insert_evm_transactions
#     compressed_data = self._compress_data(logs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 16, in _compress_data
#     json_str = json.dumps(block_data)
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\__init__.py", line 231, in dumps
#     return _default_encoder.encode(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 200, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 258, in iterencode
#     return _iterencode(o, 0)
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 180, in default
#     raise TypeError(f'Object of type {o.__class__.__name__} '
# TypeError: Object of type HexBytes is not JSON serializable
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error compressing block data: Object of type bytes is not JSON serializable
# Error processing logs for block 25018482: Object of type bytes is not JSON serializable
# Traceback (most recent call last):
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\chains\evm_models\evm_processor.py", line 213, in process_logs
#     self.mongodb_insert_ops.insert_evm_transactions(
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 61, in insert_evm_transactions
#     compressed_data = self._compress_data(logs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 16, in _compress_data
#     json_str = json.dumps(block_data)
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\__init__.py", line 231, in dumps
#     return _default_encoder.encode(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 200, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 258, in iterencode
#     return _iterencode(o, 0)
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 180, in default
#     raise TypeError(f'Object of type {o.__class__.__name__} '
# TypeError: Object of type bytes is not JSON serializable
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error compressing block data: Object of type HexBytes is not JSON serializable
# Error processing logs for block 25018481: Object of type HexBytes is not JSON serializable
# Traceback (most recent call last):
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\chains\evm_models\evm_processor.py", line 213, in process_logs
#     self.mongodb_insert_ops.insert_evm_transactions(
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 61, in insert_evm_transactions
#     compressed_data = self._compress_data(logs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 16, in _compress_data
#     json_str = json.dumps(block_data)
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\__init__.py", line 231, in dumps
#     return _default_encoder.encode(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 200, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 258, in iterencode
#     return _iterencode(o, 0)
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 180, in default
#     raise TypeError(f'Object of type {o.__class__.__name__} '
# TypeError: Object of type HexBytes is not JSON serializable
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# ...
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error compressing block data: Object of type HexBytes is not JSON serializable
# Error processing logs for block 25018437: Object of type HexBytes is not JSON serializable
# Traceback (most recent call last):
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\chains\evm_models\evm_processor.py", line 213, in process_logs
#     self.mongodb_insert_ops.insert_evm_transactions(
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 61, in insert_evm_transactions
#     compressed_data = self._compress_data(logs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 16, in _compress_data
#     json_str = json.dumps(block_data)
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\__init__.py", line 231, in dumps
#     return _default_encoder.encode(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 200, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 258, in iterencode
#     return _iterencode(o, 0)
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 180, in default
#     raise TypeError(f'Object of type {o.__class__.__name__} '
# TypeError: Object of type HexBytes is not JSON serializable
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error inserting EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM contract ABI for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error querying EVM event for network Base: current transaction is aborted, commands ignored until end of transaction block
#
# Error compressing block data: Object of type bytes is not JSON serializable
# Error processing logs for block 25018436: Object of type bytes is not JSON serializable
# Traceback (most recent call last):
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\chains\evm_models\evm_processor.py", line 213, in process_logs
#     self.mongodb_insert_ops.insert_evm_transactions(
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 61, in insert_evm_transactions
#     compressed_data = self._compress_data(logs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 16, in _compress_data
#     json_str = json.dumps(block_data)
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\__init__.py", line 231, in dumps
#     return _default_encoder.encode(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 200, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 258, in iterencode
#     return _iterencode(o, 0)
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 180, in default
#     raise TypeError(f'Object of type {o.__class__.__name__} '
# TypeError: Object of type bytes is not JSON serializable
