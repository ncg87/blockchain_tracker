# %%
import sys
import os
from pathlib import Path

# Get absolute path to project root
project_root = Path(os.getcwd()).resolve()
if project_root.name != "ncg87-blockchain_tracker":
    project_root = project_root.parent.parent  # Adjust if running from a subdirectory

sys.path.append(str(project_root))

# Add to Python path if not already there
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from config import Settings
from chains import BaseChainQuerier, BaseChainProcessor
from database import SQLDatabase, MongoDatabase, MongoQueryOperations
import logging

#logging.basicConfig(level=logging.INFO,
#                   format='%(asctime)s - %(levelname)s - %(message)s')

# %%
querier = BaseChainQuerier()
sql_database = SQLDatabase()
mongodb_database = MongoDatabase()
mongo_query_ops = MongoQueryOperations(mongodb_database)
processor = BaseChainProcessor(sql_database, mongodb_database, querier)

# %%
query = mongo_query_ops.get_recent_blocks('Base', 100)

# %%
for block in query:
    for i in range(1):
        processor.process_logs(block['block_number'], block['timestamp'])
# Out:
# Error processing logs for block 25018485: argument of type 'BoundedCache' is not iterable
# Traceback (most recent call last):
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\chains\evm_models\evm_processor.py", line 163, in process_logs
#     if sig not in self.decoder._event_signature_cache:
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: argument of type 'BoundedCache' is not iterable
# Error processing logs for block 25018484: argument of type 'BoundedCache' is not iterable
# Traceback (most recent call last):
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\chains\evm_models\evm_processor.py", line 163, in process_logs
#     if sig not in self.decoder._event_signature_cache:
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: argument of type 'BoundedCache' is not iterable
# Error processing logs for block 25018483: argument of type 'BoundedCache' is not iterable
# Traceback (most recent call last):
# ...
