# %%
import sys
import os
from pathlib import Path

# Get absolute path to project root
project_root = Path(os.getcwd()).resolve()
if project_root.name != "ncg87-blockchain_tracker":
    project_root = project_root.parent.parent  # Adjust if running from a subdirectory

sys.path.append(str(project_root))

# Add to Python path if not already there
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from config import Settings
from chains import BNBQuerier, BNBProcessor, BNBPipeline
from database import MongoDatabase, MongoInsertOperations, MongoQueryOperations, SQLDatabase
import logging

logging.basicConfig(level=logging.INFO,
                   format='%(asctime)s - %(levelname)s - %(message)s')

# %%
querier = BNBQuerier()
# Out:
# 2025-01-13 22:02:36,536 - INFO - Initialized BNB querier
# 2025-01-13 22:02:36,537 - INFO - Initializing WebSocketHandler for BNB
# 2025-01-13 22:02:36,538 - INFO - Initializing EVMWebSocketHandler for BNB

# %%
sql_database = SQLDatabase()
mongodb_database = MongoDatabase()
processor = BNBProcessor(sql_database, mongodb_database, querier)
# Out:
# 2025-01-13 22:02:36,598 - INFO - Applying schema from C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\sql\schema.sql
# 2025-01-13 22:02:37,018 - INFO - Schema applied successfully.
# 2025-01-13 22:02:37,028 - INFO - Connected to MongoDB database: blockchain
# 2025-01-13 22:02:37,044 - INFO - Indexes created for collection: Solana
# 2025-01-13 22:02:37,046 - INFO - Indexes created for collection: Bitcoin
# 2025-01-13 22:02:37,047 - INFO - Indexes created for collection: Ethereum
# 2025-01-13 22:02:37,049 - INFO - Indexes created for collection: BNB
# 2025-01-13 22:02:37,050 - INFO - Indexes created for collection: XRP
# 2025-01-13 22:02:37,051 - INFO - Indexes created for collection: Base
# 2025-01-13 22:02:37,053 - INFO - Initialized BNB processor

# %%
mongo_query_ops = MongoQueryOperations(mongodb_database)

# %%
query = mongo_query_ops.get_recent_blocks('BNB', 50)
# Out:
# 2025-01-13 22:07:26,328 - INFO - Retrieved 50 most recent blocks from the BNB collection.

# %%
for block in query:
    processor.process_logs(block['block_number'], block['timestamp'])
# Out:
# 2025-01-13 22:07:26,977 - INFO - Fetching logs for block 45608059
# 2025-01-13 22:07:27,712 - ERROR - Error querying EVM contract ABI for network BNB: no results to fetch
# 2025-01-13 22:07:27,715 - ERROR - Error querying EVM contract ABI for network BNB: no results to fetch
# 2025-01-13 22:07:27,724 - ERROR - Error querying EVM event for network BNB: the JSON object must be str, bytes or bytearray, not NoneType
# 2025-01-13 22:07:29,622 - ERROR - Error querying EVM contract ABI for network BNB: no results to fetch
# 2025-01-13 22:07:30,572 - ERROR - Error querying EVM event for network BNB: no results to fetch
# 2025-01-13 22:07:30,574 - ERROR - Error querying EVM contract ABI for network BNB: no results to fetch
# 2025-01-13 22:07:31,946 - ERROR - Error compressing block data: Object of type HexBytes is not JSON serializable
# 2025-01-13 22:07:31,946 - ERROR - Error processing logs for block 45608059: Object of type HexBytes is not JSON serializable
# Traceback (most recent call last):
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\chains\evm_models\evm_processor.py", line 118, in process_logs
#     self.mongodb_insert_ops.insert_evm_transactions(dict(decoder_logs), self.network, block_number, timestamp)
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 61, in insert_evm_transactions
#     compressed_data = self._compress_data(logs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 16, in _compress_data
#     json_str = json.dumps(block_data)
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\__init__.py", line 231, in dumps
#     return _default_encoder.encode(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 200, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 258, in iterencode
#     return _iterencode(o, 0)
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 180, in default
#     raise TypeError(f'Object of type {o.__class__.__name__} '
# TypeError: Object of type HexBytes is not JSON serializable
# 2025-01-13 22:07:31,950 - INFO - Fetching logs for block 45608049
# 2025-01-13 22:07:32,151 - ERROR - Error querying EVM contract ABI for network BNB: no results to fetch
# 2025-01-13 22:07:32,624 - ERROR - Error querying EVM event for network BNB: no results to fetch
# 2025-01-13 22:07:32,626 - ERROR - Error querying EVM contract ABI for network BNB: no results to fetch
# 2025-01-13 22:07:34,683 - ERROR - Error querying EVM event for network BNB: no results to fetch
# 2025-01-13 22:07:35,573 - ERROR - Error querying EVM contract ABI for network BNB: no results to fetch
# 2025-01-13 22:07:35,577 - ERROR - Error querying EVM event for network BNB: no results to fetch
# 2025-01-13 22:07:36,905 - ERROR - Error compressing block data: Object of type bytes is not JSON serializable
# 2025-01-13 22:07:36,906 - ERROR - Error processing logs for block 45608049: Object of type bytes is not JSON serializable
# Traceback (most recent call last):
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\chains\evm_models\evm_processor.py", line 118, in process_logs
#     self.mongodb_insert_ops.insert_evm_transactions(dict(decoder_logs), self.network, block_number, timestamp)
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 61, in insert_evm_transactions
#     compressed_data = self._compress_data(logs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 16, in _compress_data
#     json_str = json.dumps(block_data)
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\__init__.py", line 231, in dumps
#     return _default_encoder.encode(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 200, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 258, in iterencode
#     return _iterencode(o, 0)
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 180, in default
#     raise TypeError(f'Object of type {o.__class__.__name__} '
# TypeError: Object of type bytes is not JSON serializable
# 2025-01-13 22:07:36,908 - INFO - Fetching logs for block 45608048
# 2025-01-13 22:07:37,123 - ERROR - Error querying EVM contract ABI for network BNB: no results to fetch
# 2025-01-13 22:07:37,125 - ERROR - Error querying EVM contract ABI for network BNB: no results to fetch
# 2025-01-13 22:07:38,305 - ERROR - Error querying EVM contract ABI for network BNB: no results to fetch
# 2025-01-13 22:07:38,516 - ERROR - Error querying EVM contract ABI for network BNB: no results to fetch
# 2025-01-13 22:07:38,914 - ERROR - Error querying EVM event for network BNB: no results to fetch
# 2025-01-13 22:07:41,141 - ERROR - Error compressing block data: Object of type HexBytes is not JSON serializable
# 2025-01-13 22:07:41,142 - ERROR - Error processing logs for block 45608048: Object of type HexBytes is not JSON serializable
# Traceback (most recent call last):
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\chains\evm_models\evm_processor.py", line 118, in process_logs
#     self.mongodb_insert_ops.insert_evm_transactions(dict(decoder_logs), self.network, block_number, timestamp)
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 61, in insert_evm_transactions
#     compressed_data = self._compress_data(logs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 16, in _compress_data
#     json_str = json.dumps(block_data)
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\__init__.py", line 231, in dumps
#     return _default_encoder.encode(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 200, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 258, in iterencode
#     return _iterencode(o, 0)
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 180, in default
#     raise TypeError(f'Object of type {o.__class__.__name__} '
# TypeError: Object of type HexBytes is not JSON serializable
# 2025-01-13 22:07:41,143 - INFO - Fetching logs for block 45608047
# 2025-01-13 22:07:41,409 - ERROR - Error querying EVM contract ABI for network BNB: no results to fetch
# 2025-01-13 22:07:41,412 - ERROR - Error querying EVM event for network BNB: no results to fetch
# 2025-01-13 22:07:41,413 - ERROR - Error querying EVM contract ABI for network BNB: no results to fetch
# 2025-01-13 22:07:41,417 - ERROR - Error querying EVM event for network BNB: the JSON object must be str, bytes or bytearray, not NoneType
# 2025-01-13 22:07:41,561 - ERROR - Error querying EVM contract ABI for network BNB: no results to fetch
# 2025-01-13 22:07:41,561 - ERROR - Error querying EVM contract ABI for network BNB: no results to fetch
# 2025-01-13 22:07:41,986 - ERROR - Error inserting EVM event for network BNB: value too long for type character varying(100)
#
# 2025-01-13 22:07:41,988 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,040 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,040 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,043 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,044 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,073 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,074 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,075 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,076 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,116 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,118 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,118 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,176 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,207 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,213 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,258 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,280 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,336 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,377 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,379 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,393 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,438 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,461 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,480 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,523 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,523 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,542 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,596 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,647 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,647 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,658 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,681 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,729 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,730 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,739 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,789 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,809 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,850 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,852 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,867 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,890 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,936 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,937 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,938 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,943 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,944 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,994 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,995 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,996 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:42,998 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,017 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,019 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,021 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,023 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,051 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,052 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,053 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,054 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,113 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,114 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,116 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,117 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,119 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,120 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,130 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,178 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,187 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,205 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,249 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,249 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,267 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,285 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,320 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,327 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,348 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,388 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,389 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,420 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,451 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,485 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,521 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,522 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,535 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,552 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,591 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,594 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,615 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,656 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,657 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,674 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,694 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,726 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,733 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,863 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,877 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,896 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,931 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,976 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,977 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,978 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:43,980 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,003 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,005 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,007 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,008 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,095 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,095 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,096 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,098 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,106 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,107 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,109 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,110 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,113 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,115 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,117 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,119 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,133 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,151 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,170 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,188 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,210 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,233 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,249 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,271 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,306 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,314 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,331 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,352 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,368 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,387 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,412 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,427 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,449 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,471 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,488 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,514 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,527 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,549 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,571 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,589 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,607 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,630 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,649 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,668 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,690 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,708 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,731 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,752 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,769 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,794 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,808 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,829 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,848 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,869 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,890 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,914 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,928 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,958 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,959 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,961 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,962 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,971 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,972 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,973 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,974 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,998 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:44,999 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,002 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,003 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,011 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,012 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,014 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,016 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,037 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,038 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,040 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,041 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,048 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,072 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,089 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,146 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,265 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,285 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,311 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,328 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,348 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,371 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,390 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,409 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,430 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,576 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,578 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,579 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,600 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,648 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,651 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,671 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,690 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,707 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,729 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,751 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,769 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,787 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,808 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,835 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,862 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,867 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,897 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,951 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,969 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,970 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,971 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,971 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,986 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,987 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:45,988 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,006 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,007 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,008 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,009 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,047 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,049 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,051 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,052 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,060 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,079 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,080 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,082 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,085 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,085 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,103 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,122 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,140 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,164 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,180 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,241 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,241 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,254 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,275 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,309 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,320 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,369 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,369 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,381 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,405 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:07:46,425 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# ...
#
# 2025-01-13 22:13:14,387 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,389 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,390 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,406 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,407 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,409 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,410 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,428 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,430 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,433 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,434 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,460 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,485 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,490 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,504 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,523 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,542 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,566 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,583 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,601 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,623 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,643 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,667 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,682 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,702 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,725 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,742 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,761 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,786 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,804 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,822 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,844 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,862 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,885 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,903 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,923 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,941 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,974 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:14,982 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,001 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,023 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,043 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,064 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,082 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,103 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,126 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,142 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,162 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,186 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,203 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,223 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,242 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,262 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,284 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,302 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,337 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,343 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,364 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,385 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,386 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,388 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,389 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,438 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,439 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,440 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,441 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,442 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,444 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,446 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,447 - ERROR - Error querying EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,482 - ERROR - Error inserting EVM contract ABI for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,484 - ERROR - Error querying EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,490 - ERROR - Error inserting EVM event for network BNB: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-01-13 22:13:15,493 - ERROR - Error querying EVM event for network BNB: no results to fetch
# 2025-01-13 22:13:15,496 - ERROR - Error querying EVM event for network BNB: no results to fetch
# 2025-01-13 22:13:15,501 - ERROR - Error querying EVM contract ABI for network BNB: no results to fetch
# 2025-01-13 22:13:16,355 - ERROR - Error compressing block data: Object of type HexBytes is not JSON serializable
# 2025-01-13 22:13:16,355 - ERROR - Error processing logs for block 45725009: Object of type HexBytes is not JSON serializable
# Traceback (most recent call last):
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\chains\evm_models\evm_processor.py", line 118, in process_logs
#     self.mongodb_insert_ops.insert_evm_transactions(dict(decoder_logs), self.network, block_number, timestamp)
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 61, in insert_evm_transactions
#     compressed_data = self._compress_data(logs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 16, in _compress_data
#     json_str = json.dumps(block_data)
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\__init__.py", line 231, in dumps
#     return _default_encoder.encode(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 200, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 258, in iterencode
#     return _iterencode(o, 0)
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 180, in default
#     raise TypeError(f'Object of type {o.__class__.__name__} '
# TypeError: Object of type HexBytes is not JSON serializable
# 2025-01-13 22:13:16,357 - INFO - Fetching logs for block 45725008
# 2025-01-13 22:13:16,562 - ERROR - Error querying EVM event for network BNB: the JSON object must be str, bytes or bytearray, not NoneType
# 2025-01-13 22:13:16,568 - ERROR - Error querying EVM contract ABI for network BNB: no results to fetch
# 2025-01-13 22:13:16,638 - ERROR - Error querying EVM contract ABI for network BNB: no results to fetch
# 2025-01-13 22:13:19,466 - ERROR - Error compressing block data: Object of type bytes is not JSON serializable
# 2025-01-13 22:13:19,467 - ERROR - Error processing logs for block 45725008: Object of type bytes is not JSON serializable
# Traceback (most recent call last):
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\chains\evm_models\evm_processor.py", line 118, in process_logs
#     self.mongodb_insert_ops.insert_evm_transactions(dict(decoder_logs), self.network, block_number, timestamp)
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 61, in insert_evm_transactions
#     compressed_data = self._compress_data(logs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Nicko\vscodeprojects\blockchain_tracker\database\mongodb\insert_ops.py", line 16, in _compress_data
#     json_str = json.dumps(block_data)
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\__init__.py", line 231, in dumps
#     return _default_encoder.encode(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 200, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 258, in iterencode
#     return _iterencode(o, 0)
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nicko\anaconda3\envs\blockchain\Lib\json\encoder.py", line 180, in default
#     raise TypeError(f'Object of type {o.__class__.__name__} '
# TypeError: Object of type bytes is not JSON serializable

# %%
database = Database()

pipeline = BNBPipeline(database)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 database = Database()
#       3 pipeline = BNBPipeline(database)
#
# NameError: name 'Database' is not defined

# %%
logs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 logs
#
# NameError: name 'logs' is not defined

# %%
await pipeline.run(duration=10)
# Out:
# 2025-01-08 00:42:55,842 - INFO - Starting BNB pipeline in real-time mode...
# 2025-01-08 00:42:56,378 - INFO - Connected to WebSocket: BNB
# 2025-01-08 00:42:56,380 - INFO - Subscribed to BNB updates.
# 2025-01-08 00:42:58,315 - INFO - Received block: 45577923
# 2025-01-08 00:42:58,316 - INFO - Processing block 0x2b776c3 on BNB
# 2025-01-08 00:42:58,316 - INFO - Inserting block 45577923 into database
# 2025-01-08 00:42:58,331 - INFO - Block 45577923 inserted successfully
# 2025-01-08 00:43:01,266 - INFO - Received block: 45577924
# 2025-01-08 00:43:01,267 - INFO - Processing block 0x2b776c4 on BNB
# 2025-01-08 00:43:01,267 - INFO - Inserting block 45577924 into database
# 2025-01-08 00:43:01,282 - INFO - Block 45577924 inserted successfully
# 2025-01-08 00:43:04,214 - INFO - Received block: 45577925
# 2025-01-08 00:43:04,214 - INFO - Processing block 0x2b776c5 on BNB
# 2025-01-08 00:43:04,215 - INFO - Inserting block 45577925 into database
# 2025-01-08 00:43:04,218 - INFO - Block 45577925 inserted successfully
# 2025-01-08 00:43:07,567 - INFO - Received block: 45577926
# 2025-01-08 00:43:07,569 - INFO - Processing block 0x2b776c6 on BNB
# 2025-01-08 00:43:07,570 - INFO - Inserting block 45577926 into database
# 2025-01-08 00:43:07,585 - INFO - Block 45577926 inserted successfully
# 2025-01-08 00:43:07,604 - INFO - WebSocket connection stopped for BNB.
# 2025-01-08 00:43:07,605 - INFO - BNB pipeline completed in real-time mode.

# %%
querier = BNBQuerier()
print(querier.is_connected())

block = await querier.get_block()

processor = BNBProcessor(database, querier)
# Out:
# 2025-01-08 00:43:07,612 - INFO - Initialized BNB querier
# 2025-01-08 00:43:07,613 - INFO - Initializing WebSocketHandler for BNB
# 2025-01-08 00:43:07,614 - INFO - Initializing BNBWebSocketHandler for BNB
# 2025-01-08 00:43:07,801 - INFO - Fetching block latest
# 2025-01-08 00:43:07,986 - INFO - Initialized BNB processor
# True

# %%
block.proofOfAuthorityData
# Out:
# HexBytes('...')

# %%
await processor.process_block(block)
# Out:
# 2025-01-08 00:43:08,013 - INFO - Processing block 45577926 on BNB
# 2025-01-08 00:43:08,013 - INFO - Inserting block 45577926 into database
# 2025-01-08 00:43:08,017 - INFO - Block 45577926 inserted successfully

# %%
block_dict = dict(block)

# %%
len(block_dict.keys())
# Out:
# 26
